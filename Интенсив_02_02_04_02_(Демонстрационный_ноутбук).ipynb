# %% [markdown]
# <a href="https://colab.research.google.com/github/Tfviktor/ModelExplorer/blob/master/%D0%98%D0%BD%D1%82%D0%B5%D0%BD%D1%81%D0%B8%D0%B2_02_02_04_02_(%D0%94%D0%B5%D0%BC%D0%BE%D0%BD%D1%81%D1%82%D1%80%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D0%B9_%D0%BD%D0%BE%D1%83%D1%82%D0%B1%D1%83%D0%BA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install terra_ai
# Out:
# ...
#      |████████████████████████████████| 92kB 4.1MB/s
# ...

# %%
from terra_ai import терра_ии
# Out:
# Все необходимые библиотеки установлены и готовы к работе

# %% [markdown]
# # MNIST

# %%
(обучающая_выборка_о, метки_обучающей_выборки), (тестовая_выборка_о, метки_тестовой_выборки) = терра_ии.загрузить_базу('MNIST') # Загружаем данные набора MNIST
# Out:
# Загрузка данных завершена

# %%
# Отображаем примеры цифр
терра_ии.показать_примеры(
    изображения = обучающая_выборка_о,
    метки = метки_обучающей_выборки
)

# %%
терра_ии.демонстрация_МНИСТ()
# Out:
# Демонстрация готова

# %%
цифра = 3
терра_ии.показать_изменение_маски_MNIST(цифра)

# %%
терра_ии.показать_изменение_веса()
# Out:
#        Значение веса  Изменение веса  ...  Ошибка модели  Точность модели
# Эпоха                                 ...
# 0           0.003913       -0.164092  ...       0.626573         0.844050
# 1          -0.160178       -0.067431  ...       0.349788         0.904783
# 2          -0.227610       -0.043563  ...       0.312864         0.913117
# 3          -0.271173       -0.030409  ...       0.296082         0.917333
# 4          -0.301581       -0.018171  ...       0.286519         0.919933
# 5          -0.319752       -0.016385  ...       0.279384         0.921350
# 6          -0.336137       -0.009674  ...       0.274666         0.923217
# 7          -0.345811       -0.007432  ...       0.270840         0.923983
# 8          -0.353243       -0.002189  ...       0.267326         0.925517
# 9          -0.355432       -0.002144  ...       0.264474         0.926750
#
# [10 rows x 5 columns]

# %% [markdown]
# # АВТО

# %%
# Скачиваем базу автомобилей
терра_ии.загрузить_базу(
    база = 'АВТО-2',
    справка = True
)
# Out:
# Загрузка данных завершена
#
# url: https://storage.googleapis.com/aiu_bucket/car_2.zip
# Вы скачали базу с изображениями марок автомобилей.
# База состоит из двух марок: Феррари и Мерседес
# Количество изображений в базе: 2249

# %%
2249%23
# Out:
# 18

# %%
# Примеры из базы
терра_ии.показать_примеры(
    путь='/автомобили')

# %%
терра_ии.демонстрация_АВТО()
# Out:
# Демонстрация готова

# %%
терра_ии.показать_изменение_маски_АВТО(5)

# %%
терра_ии.показать_маски()
# Out:
# *** Оригинальное изображение ***
# *** Карты первого сверточного слоя ***
# *** Карты второго сверточного слоя ***
# *** Карты третьего сверточного слоя ***
# *** Карты четвертого сверточного слоя ***
